# %%
import pandas as pd

mgm = pd.read_csv("../data/mgm.csv")

mgm.head()
# Out:
#   experiment_date  mgm_day
# 0      2025-03-24        4
# 1      2025-03-31        0
# 2      2025-04-14        0
# 3      2025-05-12        0
# 4      2025-05-19        0
