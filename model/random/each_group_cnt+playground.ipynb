# %%
import numpy as np
import pandas as pd

DATA_PATH = "../../final_data/data_260119_random.csv"
TARGET_WEEK = "2026-01-05"

GROUP_COLS = ["treatment", "source", "ops_type_merged", "city_group"]
DATE_COL = "experiment_date"
LOG_COL = "log1p_user_cnt"

df = pd.read_csv(DATA_PATH)

wk = df[df[DATE_COL].astype(str) == TARGET_WEEK].copy()
wk["user_cnt_recovered"] = np.expm1(wk[LOG_COL]).round().astype("Int64")

group_user_cnt = (
    wk.groupby(GROUP_COLS, dropna=False)["user_cnt_recovered"]
      .sum()
      .reset_index(name="total_user_cnt")
      .sort_values(["ops_type_merged", "treatment", "source", "city_group"], ascending=True)
)

# 一次印出全部
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 0)

print(group_user_cnt)
# Out:
#     treatment source  ops_type_merged city_group  total_user_cnt
# 0     15x2元1張    隨機組     14天在其他尖峰預估車資         中區             190
# 1     15x2元1張    隨機組     14天在其他尖峰預估車資         北區             802
# 2     15x2元1張    隨機組     14天在其他尖峰預估車資         南區             202
# 24      15元1張    隨機組     14天在其他尖峰預估車資         中區             199
# 25      15元1張    隨機組     14天在其他尖峰預估車資         北區             833
# 26      15元1張    隨機組     14天在其他尖峰預估車資         南區             191
# 48    20x2元1張    隨機組     14天在其他尖峰預估車資         中區             190
# 49    20x2元1張    隨機組     14天在其他尖峰預估車資         北區             781
# 50    20x2元1張    隨機組     14天在其他尖峰預估車資         南區             179
# 72      20元1張    隨機組     14天在其他尖峰預估車資         中區             217
# 73      20元1張    隨機組     14天在其他尖峰預估車資         北區             751
# 74      20元1張    隨機組     14天在其他尖峰預估車資         南區             162
# 96    30x2元1張    隨機組     14天在其他尖峰預估車資         中區             198
# 97    30x2元1張    隨機組     14天在其他尖峰預估車資         北區             780
# 98    30x2元1張    隨機組     14天在其他尖峰預估車資         南區             172
# 120     30元1張    隨機組     14天在其他尖峰預估車資         中區             195
# 121     30元1張    隨機組     14天在其他尖峰預估車資         北區             774
# 122     30元1張    隨機組     14天在其他尖峰預估車資         南區             200
# 144   40x2元1張    隨機組     14天在其他尖峰預估車資         中區             203
# 145   40x2元1張    隨機組     14天在其他尖峰預估車資         北區             830
# 146   40x2元1張    隨機組     14天在其他尖峰預估車資         南區             170
# 168     40元1張    隨機組     14天在其他尖峰預估車資         中區             212
# 169     40元1張    隨機組     14天在其他尖峰預估車資         北區             773
# 170     40元1張    隨機組     14天在其他尖峰預估車資         南區             185
# 3     15x2元1張    隨機組      14天在晚尖峰預估車資         中區              85
# 4     15x2元1張    隨機組      14天在晚尖峰預估車資         北區             411
# 5     15x2元1張    隨機組      14天在晚尖峰預估車資         南區              57
# 27      15元1張    隨機組      14天在晚尖峰預估車資         中區              86
# 28      15元1張    隨機組      14天在晚尖峰預估車資         北區             375
# 29      15元1張    隨機組      14天在晚尖峰預估車資         南區              57
# 51    20x2元1張    隨機組      14天在晚尖峰預估車資         中區              91
# 52    20x2元1張    隨機組      14天在晚尖峰預估車資         北區             375
# 53    20x2元1張    隨機組      14天在晚尖峰預估車資         南區              71
# 75      20元1張    隨機組      14天在晚尖峰預估車資         中區              91
# 76      20元1張    隨機組      14天在晚尖峰預估車資         北區             351
# 77      20元1張    隨機組      14天在晚尖峰預估車資         南區              68
# 99    30x2元1張    隨機組      14天在晚尖峰預估車資         中區              90
# 100   30x2元1張    隨機組      14天在晚尖峰預估車資         北區             366
# 101   30x2元1張    隨機組      14天在晚尖峰預估車資         南區              62
# 123     30元1張    隨機組      14天在晚尖峰預估車資         中區              85
# 124     30元1張    隨機組      14天在晚尖峰預估車資         北區             376
# 125     30元1張    隨機組      14天在晚尖峰預估車資         南區              55
# 147   40x2元1張    隨機組      14天在晚尖峰預估車資         中區              96
# 148   40x2元1張    隨機組      14天在晚尖峰預估車資         北區             381
# 149   40x2元1張    隨機組      14天在晚尖峰預估車資         南區              68
# 171     40元1張    隨機組      14天在晚尖峰預估車資         中區              88
# 172     40元1張    隨機組      14天在晚尖峰預估車資         北區             360
# 173     40元1張    隨機組      14天在晚尖峰預估車資         南區              75
# 6     15x2元1張    隨機組       90天在尖峰預估車資         中區             352
# 7     15x2元1張    隨機組       90天在尖峰預估車資         北區            1428
# 8     15x2元1張    隨機組       90天在尖峰預估車資         南區             331
# 30      15元1張    隨機組       90天在尖峰預估車資         中區             357
# 31      15元1張    隨機組       90天在尖峰預估車資         北區            1309
# 32      15元1張    隨機組       90天在尖峰預估車資         南區             351
# 54    20x2元1張    隨機組       90天在尖峰預估車資         中區             305
# 55    20x2元1張    隨機組       90天在尖峰預估車資         北區            1419
# 56    20x2元1張    隨機組       90天在尖峰預估車資         南區             326
# 78      20元1張    隨機組       90天在尖峰預估車資         中區             305
# 79      20元1張    隨機組       90天在尖峰預估車資         北區            1418
# 80      20元1張    隨機組       90天在尖峰預估車資         南區             348
# 102   30x2元1張    隨機組       90天在尖峰預估車資         中區             328
# 103   30x2元1張    隨機組       90天在尖峰預估車資         北區            1356
# 104   30x2元1張    隨機組       90天在尖峰預估車資         南區             343
# 126     30元1張    隨機組       90天在尖峰預估車資         中區             331
# 127     30元1張    隨機組       90天在尖峰預估車資         北區            1387
# 128     30元1張    隨機組       90天在尖峰預估車資         南區             299
# 150   40x2元1張    隨機組       90天在尖峰預估車資         中區             326
# 151   40x2元1張    隨機組       90天在尖峰預估車資         北區            1371
# 152   40x2元1張    隨機組       90天在尖峰預估車資         南區             352
# 174     40元1張    隨機組       90天在尖峰預估車資         中區             325
# 175     40元1張    隨機組       90天在尖峰預估車資         北區            1384
# 176     40元1張    隨機組       90天在尖峰預估車資         南區             334
# 9     15x2元1張    隨機組            喚回-其他         中區             245
# 10    15x2元1張    隨機組            喚回-其他         北區             876
# 11    15x2元1張    隨機組            喚回-其他         南區             249
# 33      15元1張    隨機組            喚回-其他         中區             246
# 34      15元1張    隨機組            喚回-其他         北區             934
# 35      15元1張    隨機組            喚回-其他         南區             280
# 57    20x2元1張    隨機組            喚回-其他         中區             242
# 58    20x2元1張    隨機組            喚回-其他         北區             880
# 59    20x2元1張    隨機組            喚回-其他         南區             221
# 81      20元1張    隨機組            喚回-其他         中區             259
# 82      20元1張    隨機組            喚回-其他         北區             871
# 83      20元1張    隨機組            喚回-其他         南區             291
# 105   30x2元1張    隨機組            喚回-其他         中區             250
# 106   30x2元1張    隨機組            喚回-其他         北區             873
# 107   30x2元1張    隨機組            喚回-其他         南區             274
# 129     30元1張    隨機組            喚回-其他         中區             260
# 130     30元1張    隨機組            喚回-其他         北區             831
# 131     30元1張    隨機組            喚回-其他         南區             294
# 153   40x2元1張    隨機組            喚回-其他         中區             257
# 154   40x2元1張    隨機組            喚回-其他         北區             858
# 155   40x2元1張    隨機組            喚回-其他         南區             257
# 177     40元1張    隨機組            喚回-其他         中區             248
# 178     40元1張    隨機組            喚回-其他         北區             833
# 179     40元1張    隨機組            喚回-其他         南區             266
# 12    15x2元1張    隨機組         喚回-高優惠敏感         中區              52
# 13    15x2元1張    隨機組         喚回-高優惠敏感         北區             120
# 14    15x2元1張    隨機組         喚回-高優惠敏感         南區              47
# 36      15元1張    隨機組         喚回-高優惠敏感         中區              43
# 37      15元1張    隨機組         喚回-高優惠敏感         北區             166
# 38      15元1張    隨機組         喚回-高優惠敏感         南區              42
# 60    20x2元1張    隨機組         喚回-高優惠敏感         中區              49
# 61    20x2元1張    隨機組         喚回-高優惠敏感         北區             154
# 62    20x2元1張    隨機組         喚回-高優惠敏感         南區              46
# 84      20元1張    隨機組         喚回-高優惠敏感         中區              51
# 85      20元1張    隨機組         喚回-高優惠敏感         北區             143
# 86      20元1張    隨機組         喚回-高優惠敏感         南區              46
# 108   30x2元1張    隨機組         喚回-高優惠敏感         中區              50
# 109   30x2元1張    隨機組         喚回-高優惠敏感         北區             145
# 110   30x2元1張    隨機組         喚回-高優惠敏感         南區              33
# 132     30元1張    隨機組         喚回-高優惠敏感         中區              45
# 133     30元1張    隨機組         喚回-高優惠敏感         北區             165
# 134     30元1張    隨機組         喚回-高優惠敏感         南區              32
# 156   40x2元1張    隨機組         喚回-高優惠敏感         中區              47
# 157   40x2元1張    隨機組         喚回-高優惠敏感         北區             145
# 158   40x2元1張    隨機組         喚回-高優惠敏感         南區              39
# 180     40元1張    隨機組         喚回-高優惠敏感         中區              50
# 181     40元1張    隨機組         喚回-高優惠敏感         北區             121
# 182     40元1張    隨機組         喚回-高優惠敏感         南區              34
# 15    15x2元1張    隨機組      既有regular鞏固         中區             165
# 16    15x2元1張    隨機組      既有regular鞏固         北區             645
# 17    15x2元1張    隨機組      既有regular鞏固         南區             118
# 39      15元1張    隨機組      既有regular鞏固         中區             140
# 40      15元1張    隨機組      既有regular鞏固         北區             652
# 41      15元1張    隨機組      既有regular鞏固         南區             143
# 63    20x2元1張    隨機組      既有regular鞏固         中區             139
# 64    20x2元1張    隨機組      既有regular鞏固         北區             587
# 65    20x2元1張    隨機組      既有regular鞏固         南區             152
# 87      20元1張    隨機組      既有regular鞏固         中區             152
# 88      20元1張    隨機組      既有regular鞏固         北區             626
# 89      20元1張    隨機組      既有regular鞏固         南區             129
# 111   30x2元1張    隨機組      既有regular鞏固         中區             149
# 112   30x2元1張    隨機組      既有regular鞏固         北區             645
# 113   30x2元1張    隨機組      既有regular鞏固         南區             130
# 135     30元1張    隨機組      既有regular鞏固         中區             161
# 136     30元1張    隨機組      既有regular鞏固         北區             652
# 137     30元1張    隨機組      既有regular鞏固         南區             117
# 159   40x2元1張    隨機組      既有regular鞏固         中區             157
# 160   40x2元1張    隨機組      既有regular鞏固         北區             642
# 161   40x2元1張    隨機組      既有regular鞏固         南區             124
# 183     40元1張    隨機組      既有regular鞏固         中區             141
# 184     40元1張    隨機組      既有regular鞏固         北區             567
# 185     40元1張    隨機組      既有regular鞏固         南區             148
# 18    15x2元1張    隨機組     養成Regular-其他         中區             108
# 19    15x2元1張    隨機組     養成Regular-其他         北區             354
# 20    15x2元1張    隨機組     養成Regular-其他         南區             104
# 42      15元1張    隨機組     養成Regular-其他         中區             108
# 43      15元1張    隨機組     養成Regular-其他         北區             346
# 44      15元1張    隨機組     養成Regular-其他         南區             106
# 66    20x2元1張    隨機組     養成Regular-其他         中區              88
# 67    20x2元1張    隨機組     養成Regular-其他         北區             364
# 68    20x2元1張    隨機組     養成Regular-其他         南區             103
# 90      20元1張    隨機組     養成Regular-其他         中區              79
# 91      20元1張    隨機組     養成Regular-其他         北區             335
# 92      20元1張    隨機組     養成Regular-其他         南區             119
# 114   30x2元1張    隨機組     養成Regular-其他         中區              94
# 115   30x2元1張    隨機組     養成Regular-其他         北區             378
# 116   30x2元1張    隨機組     養成Regular-其他         南區             107
# 138     30元1張    隨機組     養成Regular-其他         中區              84
# 139     30元1張    隨機組     養成Regular-其他         北區             359
# 140     30元1張    隨機組     養成Regular-其他         南區              82
# 162   40x2元1張    隨機組     養成Regular-其他         中區              84
# 163   40x2元1張    隨機組     養成Regular-其他         北區             331
# 164   40x2元1張    隨機組     養成Regular-其他         南區             100
# 186     40元1張    隨機組     養成Regular-其他         中區              80
# 187     40元1張    隨機組     養成Regular-其他         北區             334
# 188     40元1張    隨機組     養成Regular-其他         南區             103
# 21    15x2元1張    隨機組  養成Regular-高優惠敏感         中區             117
# 22    15x2元1張    隨機組  養成Regular-高優惠敏感         北區             448
# 23    15x2元1張    隨機組  養成Regular-高優惠敏感         南區             129
# 45      15元1張    隨機組  養成Regular-高優惠敏感         中區             130
# 46      15元1張    隨機組  養成Regular-高優惠敏感         北區             415
# 47      15元1張    隨機組  養成Regular-高優惠敏感         南區             133
# 69    20x2元1張    隨機組  養成Regular-高優惠敏感         中區             124
# 70    20x2元1張    隨機組  養成Regular-高優惠敏感         北區             464
# 71    20x2元1張    隨機組  養成Regular-高優惠敏感         南區             102
# 93      20元1張    隨機組  養成Regular-高優惠敏感         中區             133
# 94      20元1張    隨機組  養成Regular-高優惠敏感         北區             446
# 95      20元1張    隨機組  養成Regular-高優惠敏感         南區             113
# 117   30x2元1張    隨機組  養成Regular-高優惠敏感         中區             113
# 118   30x2元1張    隨機組  養成Regular-高優惠敏感         北區             420
# 119   30x2元1張    隨機組  養成Regular-高優惠敏感         南區             132
# 141     30元1張    隨機組  養成Regular-高優惠敏感         中區             148
# 142     30元1張    隨機組  養成Regular-高優惠敏感         北區             428
# 143     30元1張    隨機組  養成Regular-高優惠敏感         南區             127
# 165   40x2元1張    隨機組  養成Regular-高優惠敏感         中區             132
# 166   40x2元1張    隨機組  養成Regular-高優惠敏感         北區             477
# 167   40x2元1張    隨機組  養成Regular-高優惠敏感         南區             143
# 189     40元1張    隨機組  養成Regular-高優惠敏感         中區             152
# 190     40元1張    隨機組  養成Regular-高優惠敏感         北區             444
# 191     40元1張    隨機組  養成Regular-高優惠敏感         南區             133

# %%
import pandas as pd
import numpy as np

PATH = "../../result/random/random_metrics_by_city_group.csv"

# 讀資料
df = pd.read_csv(PATH)

# 修正你打錯的 target（如果資料裡真的有這種拼字就一起修）
df["target"] = df["target"].replace({
    "nonrepeat_ccnt_per_user": "nonrepeat_cnt_per_user"
})

# 只留你要的兩個 target
targets = ["trip_cnt_per_user", "nonrepeat_cnt_per_user"]
df = df[df["target"].isin(targets)].copy()

# 定義 baseline / lgbm
baseline_models = ["baseline_lag1", "baseline_roll4"]
lgbm_models = ["lgbm_global"]   # 你的檔案裡是這個名字

# 取各 city_group、各 target 的「最佳 baseline（RMSE 最小）」
baseline_best = (
    df[df["model"].isin(baseline_models)]
      .sort_values(["city_group", "target", "RMSE"], ascending=[True, True, True])
      .groupby(["city_group", "target"], as_index=False)
      .first()
      .rename(columns={"model": "best_baseline_model", "RMSE": "best_baseline_rmse"})
      [["city_group", "target", "best_baseline_model", "best_baseline_rmse"]]
)

# 取各 city_group、各 target 的 LGBM RMSE
lgbm = (
    df[df["model"].isin(lgbm_models)]
      .rename(columns={"model": "lgbm_model", "RMSE": "lgbm_rmse"})
      [["city_group", "target", "lgbm_model", "lgbm_rmse"]]
)

# 合併並算「比(較好的)baseline好多少比例」
out = baseline_best.merge(lgbm, on=["city_group", "target"], how="inner")
out["improve_ratio"] = (out["best_baseline_rmse"] - out["lgbm_rmse"]) / out["best_baseline_rmse"]
out["improve_pct"] = out["improve_ratio"] * 100

# 排序輸出
out = out.sort_values(["target", "city_group"]).reset_index(drop=True)

print(out)

# 如要存檔：
out.to_csv("../../result/random/baseline_improvement_by_city_group.csv", index=False, encoding="utf-8-sig")
# Out:
#   city_group                  target best_baseline_model  best_baseline_rmse  \
# 0         中區  nonrepeat_cnt_per_user      baseline_roll4            0.073022
# 1         北區  nonrepeat_cnt_per_user      baseline_roll4            0.071563
# 2         南區  nonrepeat_cnt_per_user      baseline_roll4            0.051918
# 3         中區       trip_cnt_per_user      baseline_roll4            0.056941
# 4         北區       trip_cnt_per_user      baseline_roll4            0.035799
# 5         南區       trip_cnt_per_user      baseline_roll4            0.040872
#
#     lgbm_model  lgbm_rmse  improve_ratio  improve_pct
# 0  lgbm_global   0.058666       0.196607    19.660661
# 1  lgbm_global   0.027540       0.615167    61.516724
# 2  lgbm_global   0.044562       0.141679    14.167875
# 3  lgbm_global   0.045234       0.205586    20.558639
# 4  lgbm_global   0.021864       0.389268    38.926798
# 5  lgbm_global   0.038695       0.053268     5.326814

# %%
import os
import numpy as np
import pandas as pd

# =========================
# Config
# =========================
INPUT_FILES = [
    "../../result/random/random_metrics_by_city_group.csv",
    "../../result/random/random_metrics_by_ops_type_merged.csv",
    "../../result/random/random_metrics_by_treatment.csv",
]

OUT_DIR = "../../result/random"   # 你指定的路徑
os.makedirs(OUT_DIR, exist_ok=True)

TARGETS = ["trip_cnt_per_user", "nonrepeat_cnt_per_user"]
BASELINE_MODELS = ["baseline_lag1", "baseline_roll4"]
LGBM_MODEL = "lgbm_global"

# =========================
# Main
# =========================
for path in INPUT_FILES:
    df = pd.read_csv(path)

    # 找到「分組欄位」：這三份檔案都是第一欄（city_group / ops_type_merged / treatment）
    group_col = df.columns[0]

    # 修正可能的拼字錯誤（保險）
    df["target"] = df["target"].replace({
        "nonrepeat_ccnt_per_user": "nonrepeat_cnt_per_user"
    })

    df = df[df["target"].isin(TARGETS)].copy()

    # best baseline（RMSE 最小）
    baseline_best = (
        df[df["model"].isin(BASELINE_MODELS)]
          .sort_values([group_col, "target", "RMSE"], ascending=[True, True, True])
          .groupby([group_col, "target"], as_index=False)
          .first()
          .rename(columns={"model": "best_baseline_model", "RMSE": "best_baseline_rmse"})
          [[group_col, "target", "best_baseline_model", "best_baseline_rmse"]]
    )

    # lgbm rmse
    lgbm = (
        df[df["model"] == LGBM_MODEL]
          .rename(columns={"model": "lgbm_model", "RMSE": "lgbm_rmse"})
          [[group_col, "target", "lgbm_model", "lgbm_rmse"]]
    )

    out = baseline_best.merge(lgbm, on=[group_col, "target"], how="inner")
    out["improve_ratio"] = (out["best_baseline_rmse"] - out["lgbm_rmse"]) / out["best_baseline_rmse"]
    out["improve_pct"] = out["improve_ratio"] * 100

    out = out.sort_values(["target", group_col]).reset_index(drop=True)

    # 存檔
    out_name = f"baseline_improvement_by_{group_col}.csv"
    out_path = os.path.join(OUT_DIR, out_name)
    out.to_csv(out_path, index=False, encoding="utf-8-sig")

    print(f"[Saved] {out_path}  | rows={len(out)}")
# Out:
# [Saved] ../../result/random\baseline_improvement_by_city_group.csv  | rows=6
# [Saved] ../../result/random\baseline_improvement_by_ops_type_merged.csv  | rows=16
# [Saved] ../../result/random\baseline_improvement_by_treatment.csv  | rows=16
