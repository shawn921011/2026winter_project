# %% [markdown]
# # Add user_cnt

# %%
import pandas as pd

WEEKLY_PATH = "../../final_data/data_260116.csv"
DAILY_PATH  = "../data/daily_trip_merged_with_weekend_and_weather_with_coupon.csv"
OUT_PATH    = "../data/daily_trip_merged_with_weekend_and_weather_with_coupon_with_user_cnt.csv"

wk = pd.read_csv(WEEKLY_PATH)
dy = pd.read_csv(DAILY_PATH)

wk["experiment_date"] = pd.to_datetime(wk["experiment_date"])
dy["day"] = pd.to_datetime(dy["day"])

# 用週一當週別（只用來對齊，不會留在最後輸出）
dy["_week_monday"] = dy["day"] - pd.to_timedelta(dy["day"].dt.weekday, unit="D")

keys_wk = ["experiment_date", "treatment", "source", "ops_type_merged", "city_group"]
keys_dy = ["_week_monday",     "treatment", "source", "ops_type_merged", "city_group"]

wk_cnt = (
    wk.groupby(keys_wk, as_index=False)["user_cnt"]
      .max()
)

dy2 = dy.merge(
    wk_cnt,
    how="left",
    left_on=keys_dy,
    right_on=keys_wk
)

# 清掉 merge 用的欄位，不把 experiment_date 加進最後資料
dy2 = dy2.drop(columns=["_week_monday", "experiment_date"])

dy2.to_csv(OUT_PATH, index=False, encoding="utf-8-sig")
print("Saved:", OUT_PATH)
# Out:
# Saved: ../data/daily_trip_merged_with_weekend_and_weather_with_coupon_with_user_cnt.csv

# %% [markdown]
# # Takeout 8/11 week (no data)

# %%
import pandas as pd

IN_PATH  = "../data/daily_trip_merged_with_weekend_and_weather_with_coupon_with_user_cnt.csv"
OUT_PATH = "../data/daily_trip_merged_with_weekend_and_weather_with_coupon_with_user_cnt.csv"

df = pd.read_csv(IN_PATH)
df["day"] = pd.to_datetime(df["day"])

start = pd.Timestamp("2025-08-11")
end   = pd.Timestamp("2025-08-18")

before = len(df)
df2 = df[~df["day"].between(start, end, inclusive="both")].copy()
after = len(df2)

df2.to_csv(OUT_PATH, index=False, encoding="utf-8-sig")
print("Saved:", OUT_PATH)
# Out:
# Saved: ../data/daily_trip_merged_with_weekend_and_weather_with_coupon_with_user_cnt.csv

# %% [markdown]
# # per_user + NaN->0

# %%
import pandas as pd
import numpy as np

IN_PATH  = "../data/daily_trip_merged_with_weekend_and_weather_with_coupon_with_user_cnt.csv"
OUT_PATH = "../data/daily_trip_merged_add_cnt_per_user.csv"

df = pd.read_csv(IN_PATH)

# 需要轉數字、且要補 0 的欄位
base_num_cols = [
    "trip_cnt", "nonrepeat_cnt", "match_rate",
    "is_weekend_holiday", "is_rainy", "user_cnt"
]

coupon_total_cols = [
    "coupon_BD_total", "coupon_CDP_total", "coupon_folk_total", "coupon_growth_other_total",
    "coupon_MGM_total", "coupon_MKT_total", "coupon_register_total", "coupon_daily_total"
]

# (1) 轉成數字（轉不了就 NaN）
for c in base_num_cols + coupon_total_cols:
    if c in df.columns:
        df[c] = pd.to_numeric(df[c], errors="coerce")

# (2) 空值補 0（只補存在的欄位）
fill_cols = [c for c in (base_num_cols + coupon_total_cols) if c in df.columns]
df[fill_cols] = df[fill_cols].fillna(0)

# (3) 計算 per_user：user_cnt=0 時避免除以 0，直接給 0
den = df["user_cnt"].replace(0, np.nan)

df["trip_cnt_per_user"] = (df["trip_cnt"] / den).fillna(0)
df["nonrepeat_cnt_per_user"] = (df["nonrepeat_cnt"] / den).fillna(0)

# 新增：coupon_*_per_user
for c in coupon_total_cols:
    if c in df.columns:
        out_c = c.replace("_total", "_per_user")
        df[out_c] = (df[c] / den).fillna(0)

# 輸出
df.to_csv(OUT_PATH, index=False, encoding="utf-8-sig")
print("Saved:", OUT_PATH)
# Out:
# Saved: ../data/daily_trip_merged_add_cnt_per_user.csv

# %% [markdown]
# # lag

# %%
import pandas as pd
import numpy as np

IN_PATH  = "../data/daily_trip_merged_add_cnt_per_user.csv"
OUT_PATH = "../data/daily_trip_with_lag.csv"

df = pd.read_csv(IN_PATH)
df["day"] = pd.to_datetime(df["day"])

keys = ["treatment", "source", "ops_type_merged", "city_group"]

# 需要做 lag 的欄位：原本 + coupon per_user
lag_cols = [
    "trip_cnt_per_user", "nonrepeat_cnt_per_user", "match_rate",
    "coupon_BD_per_user", "coupon_CDP_per_user", "coupon_folk_per_user",
    "coupon_growth_other_per_user", "coupon_MGM_per_user", "coupon_MKT_per_user",
    "coupon_register_per_user", "coupon_daily_per_user"
]

# ensure numeric (不存在就略過)
lag_cols_exist = [c for c in lag_cols if c in df.columns]
for c in lag_cols_exist:
    df[c] = pd.to_numeric(df[c], errors="coerce")

df = df.sort_values(keys + ["day"]).reset_index(drop=True)

base = df[keys + ["day"] + lag_cols_exist].copy()

# build lag (days)
for k in range(1, 31):  # range(10, 22) = 10..21 inclusive
    lagk = base.copy()
    lagk["day"] = lagk["day"] + pd.Timedelta(days=k)  # shift forward so it aligns as "k days ago"
    lagk = lagk.rename(columns={c: f"{c}_lag{k}" for c in lag_cols_exist})
    df = df.merge(lagk, on=keys + ["day"], how="left")

df.to_csv(OUT_PATH, index=False, encoding="utf-8-sig")
print("Saved:", OUT_PATH)
# Out:
# Saved: ../data/daily_trip_with_lag.csv

# %% [markdown]
# # mgm

# %%
import pandas as pd
import numpy as np

IN_PATH  = "../data/daily_trip_with_lag.csv"
OUT_PATH = "../data/daily_trip_with_lag_mgm.csv"

df = pd.read_csv(IN_PATH)
df["day"] = pd.to_datetime(df["day"])

# MGM date ranges (inclusive)
mgm_ranges = [
    ("2025-07-28", "2025-08-03"),
    ("2025-08-27", "2025-09-02"),
    ("2025-09-27", "2025-10-06"),
    ("2025-10-23", "2025-10-31"),
    ("2025-11-26", "2025-12-02"),
    ("2025-12-24", "2026-01-01"),
]

mgm_day = pd.Series(False, index=df.index)
for s, e in mgm_ranges:
    s = pd.Timestamp(s)
    e = pd.Timestamp(e)
    mgm_day |= df["day"].between(s, e, inclusive="both")

df["mgm_day"] = mgm_day.astype(int)

df.to_csv(OUT_PATH, index=False, encoding="utf-8-sig")
print("Saved:", OUT_PATH)
# Out:
# Saved: ../data/daily_trip_with_lag_mgm.csv

# %%
import pandas as pd

prep = pd.read_csv("../data/daily_trip_with_lag_mgm.csv")
prep.describe()
# Out:
#            trip_cnt  nonrepeat_cnt    match_rate  is_weekend_holiday  \
# count  19968.000000   19968.000000  19968.000000        19968.000000
# mean       7.534255      10.672726      0.695024            0.326923
# std       12.493974      18.577814      0.336185            0.469101
# min        0.000000       0.000000      0.000000            0.000000
# 25%        1.000000       2.000000      0.571429            0.000000
# 50%        3.000000       5.000000      0.800000            0.000000
# 75%        8.000000      11.000000      1.000000            1.000000
# max      172.000000     306.000000      1.000000            1.000000
#
#            is_rainy  coupon_BD_total  coupon_CDP_total  coupon_folk_total  \
# count  19968.000000     19968.000000      19968.000000       19968.000000
# mean       0.169979        85.313452        169.100411         384.806741
# std        0.291184       122.586503        323.728056         527.467476
# min        0.000000         0.000000          0.000000           0.000000
# 25%        0.000000        19.000000         22.000000          60.000000
# 50%        0.000000        45.000000         60.000000         205.000000
# 75%        0.250000       103.000000        177.000000         491.000000
# max        1.000000      1680.000000       3736.000000        4414.000000
#
#        coupon_growth_other_total  coupon_MGM_total  coupon_MKT_total  \
# count               19968.000000      19968.000000      19968.000000
# mean                   24.013421         10.632863          5.326973
# std                   119.469682         56.715093         11.274082
# min                     0.000000          0.000000          0.000000
# 25%                     0.000000          0.000000          0.000000
# 50%                     0.000000          0.000000          0.000000
# 75%                     4.000000          4.000000          5.000000
# max                  2022.000000       2945.000000        109.000000
#
#        coupon_register_total  coupon_daily_total      user_cnt  \
# count           19968.000000        19968.000000  19968.000000
# mean                6.972907            0.127103    515.797376
# std                14.747589            0.471314    728.719338
# min                 0.000000            0.000000      6.000000
# 25%                 0.000000            0.000000    126.000000
# 50%                 1.000000            0.000000    262.500000
# 75%                 8.000000            0.000000    619.000000
# max               189.000000            8.000000   9388.000000
#
#        trip_cnt_per_user  nonrepeat_cnt_per_user  coupon_BD_per_user  \
# count       19968.000000            19968.000000        19968.000000
# mean            0.015342                0.020989            0.196745
# std             0.014290                0.018722            0.148910
# min             0.000000                0.000000            0.000000
# 25%             0.005305                0.007837            0.088023
# 50%             0.011976                0.016598            0.167696
# 75%             0.022222                0.029851            0.273585
# max             0.162791                0.200000            1.156863
#
#        coupon_CDP_per_user  coupon_folk_per_user  \
# count         19968.000000          19968.000000
# mean              0.304469              1.128537
# std               0.226814              0.706093
# min               0.000000              0.000000
# 25%               0.127835              0.939001
# 50%               0.250000              0.990291
# 75%               0.433962              1.952729
# max               1.303131              2.074866
#
#        coupon_growth_other_per_user  coupon_MGM_per_user  coupon_MKT_per_user  \
# count                  19968.000000         19968.000000         19968.000000
# mean                       0.045275             0.015805             0.015972
# std                        0.193776             0.044112             0.035697
# min                        0.000000             0.000000             0.000000
# 25%                        0.000000             0.000000             0.000000
# 50%                        0.000000             0.000000             0.000000
# 75%                        0.008496             0.015435             0.011583
# max                        1.639344             1.067669             0.365385
#
#        coupon_register_per_user  coupon_daily_per_user  \
# count              19968.000000           19968.000000
# mean                   0.015650               0.000190
# std                    0.024555               0.000899
# min                    0.000000               0.000000
# 25%                    0.000000               0.000000
# 50%                    0.004046               0.000000
# 75%                    0.022013               0.000000
# max                    0.225000               0.014493
#
#        trip_cnt_per_user_lag1  nonrepeat_cnt_per_user_lag1  match_rate_lag1  \
# count            19728.000000                 19728.000000     19728.000000
# mean                 0.015348                     0.021015         0.694324
# std                  0.014311                     0.018763         0.336457
# min                  0.000000                     0.000000         0.000000
# 25%                  0.005289                     0.007812         0.571429
# 50%                  0.011976                     0.016611         0.800000
# 75%                  0.022222                     0.029926         1.000000
# max                  0.162791                     0.200000         1.000000
#
#        coupon_BD_per_user_lag1  coupon_CDP_per_user_lag1  \
# count             19728.000000              19728.000000
# mean                  0.197519                  0.307114
# std                   0.149136                  0.226566
# min                   0.000000                  0.000000
# 25%                   0.088407                  0.131873
# 50%                   0.168675                  0.253489
# 75%                   0.274390                  0.435897
# max                   1.156863                  1.303131
#
#        coupon_folk_per_user_lag1  coupon_growth_other_per_user_lag1  \
# count               19728.000000                       19728.000000
# mean                    1.128251                           0.045808
# std                     0.705865                           0.194891
# min                     0.000000                           0.000000
# 25%                     0.939394                           0.000000
# 50%                     0.990369                           0.000000
# 75%                     1.953144                           0.008850
# max                     2.074866                           1.639344
#
#        coupon_MGM_per_user_lag1  coupon_MKT_per_user_lag1  \
# count              19728.000000              19728.000000
# mean                   0.015990                  0.016089
# std                    0.044346                  0.035842
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000000
# 75%                    0.015812                  0.011648
# max                    1.067669                  0.365385
#
#        coupon_register_per_user_lag1  coupon_daily_per_user_lag1  \
# count                   19728.000000                19728.000000
# mean                        0.015655                    0.000192
# std                         0.024532                    0.000904
# min                         0.000000                    0.000000
# 25%                         0.000000                    0.000000
# 50%                         0.004082                    0.000000
# 75%                         0.022013                    0.000000
# max                         0.225000                    0.014493
#
#        trip_cnt_per_user_lag2  nonrepeat_cnt_per_user_lag2  match_rate_lag2  \
# count            19488.000000                 19488.000000     19488.000000
# mean                 0.015320                     0.021000         0.693853
# std                  0.014311                     0.018790         0.336660
# min                  0.000000                     0.000000         0.000000
# 25%                  0.005253                     0.007812         0.571429
# 50%                  0.011946                     0.016581         0.800000
# 75%                  0.022222                     0.029901         1.000000
# max                  0.162791                     0.200000         1.000000
#
#        coupon_BD_per_user_lag2  coupon_CDP_per_user_lag2  \
# count             19488.000000              19488.000000
# mean                  0.198238                  0.309682
# std                   0.149406                  0.226406
# min                   0.000000                  0.000000
# 25%                   0.088871                  0.135101
# 50%                   0.169541                  0.256847
# 75%                   0.275094                  0.438502
# max                   1.156863                  1.303131
#
#        coupon_folk_per_user_lag2  coupon_growth_other_per_user_lag2  \
# count               19488.000000                       19488.000000
# mean                    1.127830                           0.046353
# std                     0.705557                           0.196024
# min                     0.000000                           0.000000
# 25%                     0.939592                           0.000000
# 50%                     0.990476                           0.000000
# 75%                     1.953575                           0.009062
# max                     2.074866                           1.639344
#
#        coupon_MGM_per_user_lag2  coupon_MKT_per_user_lag2  \
# count              19488.000000              19488.000000
# mean                   0.016179                  0.016208
# std                    0.044584                  0.035989
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000000
# 75%                    0.016304                  0.011773
# max                    1.067669                  0.365385
#
#        coupon_register_per_user_lag2  coupon_daily_per_user_lag2  \
# count                   19488.000000                19488.000000
# mean                        0.015654                    0.000194
# std                         0.024503                    0.000909
# min                         0.000000                    0.000000
# 25%                         0.000000                    0.000000
# 50%                         0.004111                    0.000000
# 75%                         0.022013                    0.000000
# max                         0.225000                    0.014493
#
#        trip_cnt_per_user_lag3  nonrepeat_cnt_per_user_lag3  match_rate_lag3  \
# count            19248.000000                 19248.000000     19248.000000
# mean                 0.015291                     0.020979         0.693120
# std                  0.014310                     0.018808         0.337027
# min                  0.000000                     0.000000         0.000000
# 25%                  0.005208                     0.007782         0.571429
# 50%                  0.011905                     0.016575         0.800000
# 75%                  0.022161                     0.029851         1.000000
# max                  0.162791                     0.200000         1.000000
#
#        coupon_BD_per_user_lag3  coupon_CDP_per_user_lag3  \
# count             19248.000000              19248.000000
# mean                  0.198239                  0.312210
# std                   0.149486                  0.226302
# min                   0.000000                  0.000000
# 25%                   0.088816                  0.137733
# 50%                   0.169643                  0.260090
# 75%                   0.275109                  0.440433
# max                   1.156863                  1.303131
#
#        coupon_folk_per_user_lag3  coupon_growth_other_per_user_lag3  \
# count               19248.000000                       19248.000000
# mean                    1.127274                           0.046911
# std                     0.705175                           0.197178
# min                     0.000000                           0.000000
# 25%                     0.939454                           0.000000
# 50%                     0.990546                           0.000000
# 75%                     1.953505                           0.009346
# max                     2.074866                           1.639344
#
#        coupon_MGM_per_user_lag3  coupon_MKT_per_user_lag3  \
# count              19248.000000              19248.000000
# mean                   0.016368                  0.016330
# std                    0.044826                  0.036139
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000000
# 75%                    0.016667                  0.011848
# max                    1.067669                  0.365385
#
#        coupon_register_per_user_lag3  coupon_daily_per_user_lag3  \
# count                   19248.000000                19248.000000
# mean                        0.015641                    0.000195
# std                         0.024464                    0.000914
# min                         0.000000                    0.000000
# 25%                         0.000000                    0.000000
# 50%                         0.004128                    0.000000
# 75%                         0.022013                    0.000000
# max                         0.225000                    0.014493
#
#        trip_cnt_per_user_lag4  nonrepeat_cnt_per_user_lag4  match_rate_lag4  \
# count            19008.000000                 19008.000000     19008.000000
# mean                 0.015317                     0.021046         0.692321
# std                  0.014329                     0.018851         0.336785
# min                  0.000000                     0.000000         0.000000
# 25%                  0.005214                     0.007812         0.571429
# 50%                  0.011963                     0.016620         0.800000
# 75%                  0.022222                     0.029959         1.000000
# max                  0.162791                     0.200000         1.000000
#
#        coupon_BD_per_user_lag4  coupon_CDP_per_user_lag4  \
# count             19008.000000              19008.000000
# mean                  0.198236                  0.314640
# std                   0.149566                  0.226309
# min                   0.000000                  0.000000
# 25%                   0.088674                  0.140489
# 50%                   0.169870                  0.262774
# 75%                   0.275285                  0.443182
# max                   1.156863                  1.303131
#
#        coupon_folk_per_user_lag4  coupon_growth_other_per_user_lag4  \
# count               19008.000000                       19008.000000
# mean                    1.126609                           0.047485
# std                     0.704720                           0.198353
# min                     0.000000                           0.000000
# 25%                     0.939217                           0.000000
# 50%                     0.990532                           0.000572
# 75%                     1.953125                           0.009569
# max                     2.074866                           1.639344
#
#        coupon_MGM_per_user_lag4  coupon_MKT_per_user_lag4  \
# count              19008.000000              19008.000000
# mean                   0.016559                  0.016453
# std                    0.045073                  0.036291
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000537
# 75%                    0.016967                  0.011932
# max                    1.067669                  0.365385
#
#        coupon_register_per_user_lag4  coupon_daily_per_user_lag4  \
# count                   19008.000000                19008.000000
# mean                        0.015622                    0.000197
# std                         0.024419                    0.000919
# min                         0.000000                    0.000000
# 25%                         0.000000                    0.000000
# 50%                         0.004167                    0.000000
# 75%                         0.021987                    0.000000
# max                         0.225000                    0.014493
#
#        trip_cnt_per_user_lag5  nonrepeat_cnt_per_user_lag5  match_rate_lag5  \
# count            18768.000000                 18768.000000     18768.000000
# mean                 0.015370                     0.021135         0.692298
# std                  0.014365                     0.018904         0.336225
# min                  0.000000                     0.000000         0.000000
# 25%                  0.005263                     0.007874         0.571429
# 50%                  0.011991                     0.016667         0.794118
# 75%                  0.022222                     0.030075         1.000000
# max                  0.162791                     0.200000         1.000000
#
#        coupon_BD_per_user_lag5  coupon_CDP_per_user_lag5  \
# count             18768.000000              18768.000000
# mean                  0.198212                  0.316996
# std                   0.149635                  0.226395
# min                   0.000000                  0.000000
# 25%                   0.088608                  0.142857
# 50%                   0.169877                  0.266055
# 75%                   0.275426                  0.445255
# max                   1.156863                  1.303131
#
#        coupon_folk_per_user_lag5  coupon_growth_other_per_user_lag5  \
# count               18768.000000                       18768.000000
# mean                    1.125848                           0.048074
# std                     0.704205                           0.199548
# min                     0.000000                           0.000000
# 25%                     0.939024                           0.000000
# 50%                     0.990425                           0.000690
# 75%                     1.952591                           0.009967
# max                     2.074866                           1.639344
#
#        coupon_MGM_per_user_lag5  coupon_MKT_per_user_lag5  \
# count              18768.000000              18768.000000
# mean                   0.016748                  0.016580
# std                    0.045325                  0.036446
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000627
# 75%                    0.017391                  0.012012
# max                    1.067669                  0.365385
#
#        coupon_register_per_user_lag5  coupon_daily_per_user_lag5  \
# count                   18768.000000                18768.000000
# mean                        0.015592                    0.000199
# std                         0.024359                    0.000924
# min                         0.000000                    0.000000
# 25%                         0.000000                    0.000000
# 50%                         0.004167                    0.000000
# 75%                         0.021978                    0.000000
# max                         0.225000                    0.014493
#
#        trip_cnt_per_user_lag6  nonrepeat_cnt_per_user_lag6  match_rate_lag6  \
# count            18528.000000                 18528.000000     18528.000000
# mean                 0.015413                     0.021223         0.692213
# std                  0.014395                     0.018951         0.335527
# min                  0.000000                     0.000000         0.000000
# 25%                  0.005296                     0.007935         0.571429
# 50%                  0.012048                     0.016760         0.791667
# 75%                  0.022306                     0.030175         1.000000
# max                  0.162791                     0.200000         1.000000
#
#        coupon_BD_per_user_lag6  coupon_CDP_per_user_lag6  \
# count             18528.000000              18528.000000
# mean                  0.198168                  0.319384
# std                   0.149702                  0.226474
# min                   0.000000                  0.000000
# 25%                   0.088496                  0.145878
# 50%                   0.169978                  0.269092
# 75%                   0.275426                  0.448276
# max                   1.156863                  1.303131
#
#        coupon_folk_per_user_lag6  coupon_growth_other_per_user_lag6  \
# count               18528.000000                       18528.000000
# mean                    1.124972                           0.048677
# std                     0.703621                           0.200765
# min                     0.000000                           0.000000
# 25%                     0.938663                           0.000000
# 50%                     0.990144                           0.000723
# 75%                     1.951637                           0.010485
# max                     2.074866                           1.639344
#
#        coupon_MGM_per_user_lag6  coupon_MKT_per_user_lag6  \
# count              18528.000000              18528.000000
# mean                   0.016935                  0.016710
# std                    0.045582                  0.036604
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000692
# 75%                    0.017621                  0.012111
# max                    1.067669                  0.365385
#
#        coupon_register_per_user_lag6  coupon_daily_per_user_lag6  \
# count                   18528.000000                18528.000000
# mean                        0.015552                    0.000200
# std                         0.024282                    0.000929
# min                         0.000000                    0.000000
# 25%                         0.000000                    0.000000
# 50%                         0.004167                    0.000000
# 75%                         0.021902                    0.000000
# max                         0.225000                    0.014493
#
#        trip_cnt_per_user_lag7  nonrepeat_cnt_per_user_lag7  match_rate_lag7  \
# count            18288.000000                 18288.000000     18288.000000
# mean                 0.015472                     0.021318         0.692980
# std                  0.014430                     0.019004         0.334645
# min                  0.000000                     0.000000         0.000000
# 25%                  0.005348                     0.007965         0.571429
# 50%                  0.012072                     0.016813         0.792175
# 75%                  0.022363                     0.030303         1.000000
# max                  0.162791                     0.200000         1.000000
#
#        coupon_BD_per_user_lag7  coupon_CDP_per_user_lag7  \
# count             18288.000000              18288.000000
# mean                  0.198197                  0.321775
# std                   0.149707                  0.226570
# min                   0.000000                  0.000000
# 25%                   0.088496                  0.148472
# 50%                   0.170441                  0.272727
# 75%                   0.275109                  0.450028
# max                   1.156863                  1.303131
#
#        coupon_folk_per_user_lag7  coupon_growth_other_per_user_lag7  \
# count               18288.000000                       18288.000000
# mean                    1.123987                           0.049297
# std                     0.702963                           0.202005
# min                     0.000000                           0.000000
# 25%                     0.938355                           0.000000
# 50%                     0.989724                           0.000788
# 75%                     1.950658                           0.010889
# max                     2.074866                           1.639344
#
#        coupon_MGM_per_user_lag7  coupon_MKT_per_user_lag7  \
# count              18288.000000              18288.000000
# mean                   0.017120                  0.016843
# std                    0.045842                  0.036764
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000729
# 75%                    0.017881                  0.012251
# max                    1.067669                  0.365385
#
#        coupon_register_per_user_lag7  coupon_daily_per_user_lag7  \
# count                   18288.000000                18288.000000
# mean                        0.015497                    0.000202
# std                         0.024185                    0.000934
# min                         0.000000                    0.000000
# 25%                         0.000000                    0.000000
# 50%                         0.004167                    0.000000
# 75%                         0.021873                    0.000000
# max                         0.225000                    0.014493
#
#        trip_cnt_per_user_lag8  nonrepeat_cnt_per_user_lag8  match_rate_lag8  \
# count            18048.000000                 18048.000000     18048.000000
# mean                 0.015515                     0.021398         0.692968
# std                  0.014451                     0.019044         0.333882
# min                  0.000000                     0.000000         0.000000
# 25%                  0.005386                     0.008032         0.571429
# 50%                  0.012121                     0.016949         0.790454
# 75%                  0.022472                     0.030364         1.000000
# max                  0.162791                     0.200000         1.000000
#
#        coupon_BD_per_user_lag8  coupon_CDP_per_user_lag8  \
# count             18048.000000              18048.000000
# mean                  0.198669                  0.324090
# std                   0.149859                  0.226746
# min                   0.000000                  0.000000
# 25%                   0.088900                  0.151065
# 50%                   0.170960                  0.275658
# 75%                   0.275641                  0.452454
# max                   1.156863                  1.303131
#
#        coupon_folk_per_user_lag8  coupon_growth_other_per_user_lag8  \
# count               18048.000000                       18048.000000
# mean                    1.123701                           0.049932
# std                     0.702704                           0.203268
# min                     0.000000                           0.000000
# 25%                     0.939089                           0.000000
# 50%                     0.989868                           0.000916
# 75%                     1.951468                           0.011050
# max                     2.074866                           1.639344
#
#        coupon_MGM_per_user_lag8  coupon_MKT_per_user_lag8  \
# count              18048.000000              18048.000000
# mean                   0.017248                  0.017001
# std                    0.046045                  0.036944
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000833
# 75%                    0.018182                  0.012386
# max                    1.067669                  0.365385
#
#        coupon_register_per_user_lag8  coupon_daily_per_user_lag8  \
# count                   18048.000000                18048.000000
# mean                        0.015503                    0.000203
# std                         0.024139                    0.000936
# min                         0.000000                    0.000000
# 25%                         0.000000                    0.000000
# 50%                         0.004219                    0.000000
# 75%                         0.021898                    0.000000
# max                         0.225000                    0.014493
#
#        trip_cnt_per_user_lag9  nonrepeat_cnt_per_user_lag9  match_rate_lag9  \
# count            17832.000000                 17832.000000     17832.000000
# mean                 0.015504                     0.021418         0.692156
# std                  0.014446                     0.019063         0.333562
# min                  0.000000                     0.000000         0.000000
# 25%                  0.005385                     0.008032         0.571429
# 50%                  0.012121                     0.016949         0.787689
# 75%                  0.022418                     0.030409         1.000000
# max                  0.162791                     0.200000         1.000000
#
#        coupon_BD_per_user_lag9  coupon_CDP_per_user_lag9  \
# count             17832.000000              17832.000000
# mean                  0.198957                  0.326412
# std                   0.149999                  0.226899
# min                   0.000000                  0.000000
# 25%                   0.089147                  0.153595
# 50%                   0.171176                  0.278846
# 75%                   0.275804                  0.454545
# max                   1.156863                  1.303131
#
#        coupon_folk_per_user_lag9  coupon_growth_other_per_user_lag9  \
# count               17832.000000                       17832.000000
# mean                    1.121785                           0.050524
# std                     0.703122                           0.204423
# min                     0.000000                           0.000000
# 25%                     0.939024                           0.000000
# 50%                     0.989894                           0.001007
# 75%                     1.951807                           0.011364
# max                     2.074866                           1.639344
#
#        coupon_MGM_per_user_lag9  coupon_MKT_per_user_lag9  \
# count              17832.000000              17832.000000
# mean                   0.017260                  0.017156
# std                    0.046144                  0.037104
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000987
# 75%                    0.018349                  0.012594
# max                    1.067669                  0.365385
#
#        coupon_register_per_user_lag9  coupon_daily_per_user_lag9  \
# count                   17832.000000                17832.000000
# mean                        0.015492                    0.000205
# std                         0.024075                    0.000938
# min                         0.000000                    0.000000
# 25%                         0.000000                    0.000000
# 50%                         0.004270                    0.000000
# 75%                         0.021978                    0.000000
# max                         0.225000                    0.014493
#
#        trip_cnt_per_user_lag10  nonrepeat_cnt_per_user_lag10  \
# count             17616.000000                  17616.000000
# mean                  0.015489                      0.021409
# std                   0.014400                      0.019030
# min                   0.000000                      0.000000
# 25%                   0.005391                      0.008032
# 50%                   0.012121                      0.016949
# 75%                   0.022388                      0.030430
# max                   0.162791                      0.200000
#
#        match_rate_lag10  coupon_BD_per_user_lag10  coupon_CDP_per_user_lag10  \
# count      17616.000000              17616.000000               17616.000000
# mean           0.692555                  0.199294                   0.328665
# std            0.333124                  0.150079                   0.227125
# min            0.000000                  0.000000                   0.000000
# 25%            0.571429                  0.089302                   0.155837
# 50%            0.789474                  0.171674                   0.281751
# 75%            1.000000                  0.275897                   0.457299
# max            1.000000                  1.156863                   1.303131
#
#        coupon_folk_per_user_lag10  coupon_growth_other_per_user_lag10  \
# count                17616.000000                        17616.000000
# mean                     1.119748                            0.051131
# std                      0.703480                            0.205599
# min                      0.000000                            0.000000
# 25%                      0.939001                            0.000000
# 50%                      0.989899                            0.001074
# 75%                      1.951904                            0.011696
# max                      2.074866                            1.639344
#
#        coupon_MGM_per_user_lag10  coupon_MKT_per_user_lag10  \
# count               17616.000000               17616.000000
# mean                    0.017227                   0.017315
# std                     0.046150                   0.037266
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.001100
# 75%                     0.018244                   0.012832
# max                     1.067669                   0.365385
#
#        coupon_register_per_user_lag10  coupon_daily_per_user_lag10  \
# count                    17616.000000                 17616.000000
# mean                         0.015468                     0.000206
# std                          0.023992                     0.000940
# min                          0.000000                     0.000000
# 25%                          0.000000                     0.000000
# 50%                          0.004274                     0.000000
# 75%                          0.022014                     0.000000
# max                          0.225000                     0.014493
#
#        trip_cnt_per_user_lag11  nonrepeat_cnt_per_user_lag11  \
# count             17400.000000                  17400.000000
# mean                  0.015417                      0.021225
# std                   0.014369                      0.018894
# min                   0.000000                      0.000000
# 25%                   0.005348                      0.007952
# 50%                   0.012048                      0.016760
# 75%                   0.022310                      0.030227
# max                   0.162791                      0.200000
#
#        match_rate_lag11  coupon_BD_per_user_lag11  coupon_CDP_per_user_lag11  \
# count      17400.000000              17400.000000               17400.000000
# mean           0.693637                  0.199595                   0.330837
# std            0.333705                  0.150151                   0.227430
# min            0.000000                  0.000000                   0.000000
# 25%            0.571429                  0.089686                   0.157688
# 50%            0.793103                  0.172102                   0.284958
# 75%            1.000000                  0.276024                   0.460201
# max            1.000000                  1.156863                   1.303131
#
#        coupon_folk_per_user_lag11  coupon_growth_other_per_user_lag11  \
# count                17400.000000                        17400.000000
# mean                     1.117475                            0.051753
# std                      0.703738                            0.206794
# min                      0.000000                            0.000000
# 25%                      0.938488                            0.000000
# 50%                      0.989860                            0.001205
# 75%                      1.951331                            0.011905
# max                      2.074866                            1.639344
#
#        coupon_MGM_per_user_lag11  coupon_MKT_per_user_lag11  \
# count               17400.000000               17400.000000
# mean                    0.017113                   0.017477
# std                     0.045979                   0.037431
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.001269
# 75%                     0.018072                   0.013223
# max                     1.067669                   0.365385
#
#        coupon_register_per_user_lag11  coupon_daily_per_user_lag11  \
# count                    17400.000000                 17400.000000
# mean                         0.015429                     0.000208
# std                          0.023884                     0.000942
# min                          0.000000                     0.000000
# 25%                          0.000000                     0.000000
# 50%                          0.004302                     0.000000
# 75%                          0.022039                     0.000000
# max                          0.225000                     0.014493
#
#        trip_cnt_per_user_lag12  nonrepeat_cnt_per_user_lag12  \
# count             17184.000000                  17184.000000
# mean                  0.015292                      0.020889
# std                   0.014222                      0.018384
# min                   0.000000                      0.000000
# 25%                   0.005310                      0.007874
# 50%                   0.011976                      0.016611
# 75%                   0.022184                      0.029851
# max                   0.162791                      0.186047
#
#        match_rate_lag12  coupon_BD_per_user_lag12  coupon_CDP_per_user_lag12  \
# count      17184.000000              17184.000000               17184.000000
# mean           0.695682                  0.199875                   0.334482
# std            0.334052                  0.150204                   0.226366
# min            0.000000                  0.000000                   0.000000
# 25%            0.583333                  0.089796                   0.161905
# 50%            0.800000                  0.172414                   0.288209
# 75%            1.000000                  0.276079                   0.462786
# max            1.000000                  1.156863                   1.303131
#
#        coupon_folk_per_user_lag12  coupon_growth_other_per_user_lag12  \
# count                17184.000000                        17184.000000
# mean                     1.114934                            0.052393
# std                      0.703890                            0.208011
# min                      0.000000                            0.000000
# 25%                      0.937627                            0.000000
# 50%                      0.989622                            0.001277
# 75%                      1.950000                            0.012500
# max                      2.074866                            1.639344
#
#        coupon_MGM_per_user_lag12  coupon_MKT_per_user_lag12  \
# count               17184.000000               17184.000000
# mean                    0.016967                   0.017420
# std                     0.045794                   0.037275
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.001309
# 75%                     0.017660                   0.013223
# max                     1.067669                   0.365385
#
#        coupon_register_per_user_lag12  coupon_daily_per_user_lag12  \
# count                    17184.000000                 17184.000000
# mean                         0.015376                     0.000210
# std                          0.023750                     0.000944
# min                          0.000000                     0.000000
# 25%                          0.000000                     0.000000
# 50%                          0.004329                     0.000000
# 75%                          0.022068                     0.000000
# max                          0.225000                     0.014493
#
#        trip_cnt_per_user_lag13  nonrepeat_cnt_per_user_lag13  \
# count             16968.000000                  16968.000000
# mean                  0.015308                      0.020916
# std                   0.014222                      0.018388
# min                   0.000000                      0.000000
# 25%                   0.005345                      0.007905
# 50%                   0.012000                      0.016626
# 75%                   0.022184                      0.029851
# max                   0.162791                      0.186047
#
#        match_rate_lag13  coupon_BD_per_user_lag13  coupon_CDP_per_user_lag13  \
# count      16968.000000              16968.000000               16968.000000
# mean           0.696055                  0.200701                   0.338256
# std            0.333540                  0.150277                   0.225385
# min            0.000000                  0.000000                   0.000000
# 25%            0.583333                  0.090226                   0.166348
# 50%            0.800000                  0.173519                   0.291339
# 75%            1.000000                  0.276667                   0.465909
# max            1.000000                  1.156863                   1.303131
#
#        coupon_folk_per_user_lag13  coupon_growth_other_per_user_lag13  \
# count                16968.000000                        16968.000000
# mean                     1.112165                            0.053046
# std                      0.703954                            0.209249
# min                      0.000000                            0.000000
# 25%                      0.936782                            0.000000
# 50%                      0.989301                            0.001332
# 75%                      1.948847                            0.012821
# max                      2.074866                            1.639344
#
#        coupon_MGM_per_user_lag13  coupon_MKT_per_user_lag13  \
# count               16968.000000               16968.000000
# mean                    0.016752                   0.017357
# std                     0.045529                   0.037096
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.001383
# 75%                     0.017241                   0.013010
# max                     1.067669                   0.365385
#
#        coupon_register_per_user_lag13  coupon_daily_per_user_lag13  \
# count                    16968.000000                 16968.000000
# mean                         0.015314                     0.000211
# std                          0.023592                     0.000945
# min                          0.000000                     0.000000
# 25%                          0.000000                     0.000000
# 50%                          0.004367                     0.000000
# 75%                          0.022139                     0.000000
# max                          0.225000                     0.014493
#
#        trip_cnt_per_user_lag14  nonrepeat_cnt_per_user_lag14  \
# count             16752.000000                  16752.000000
# mean                  0.015337                      0.020965
# std                   0.014213                      0.018392
# min                   0.000000                      0.000000
# 25%                   0.005383                      0.007937
# 50%                   0.012048                      0.016667
# 75%                   0.022202                      0.029851
# max                   0.162791                      0.186047
#
#        match_rate_lag14  coupon_BD_per_user_lag14  coupon_CDP_per_user_lag14  \
# count      16752.000000              16752.000000               16752.000000
# mean           0.696091                  0.201435                   0.342031
# std            0.333002                  0.150367                   0.224426
# min            0.000000                  0.000000                   0.000000
# 25%            0.583333                  0.090909                   0.170732
# 50%            0.800000                  0.174011                   0.294620
# 75%            1.000000                  0.277311                   0.467742
# max            1.000000                  1.156863                   1.303131
#
#        coupon_folk_per_user_lag14  coupon_growth_other_per_user_lag14  \
# count                16752.000000                        16752.000000
# mean                     1.109206                            0.053717
# std                      0.703939                            0.210510
# min                      0.000000                            0.000000
# 25%                      0.935945                            0.000000
# 50%                      0.988764                            0.001410
# 75%                      1.947417                            0.013158
# max                      2.018519                            1.639344
#
#        coupon_MGM_per_user_lag14  coupon_MKT_per_user_lag14  \
# count               16752.000000               16752.000000
# mean                    0.016455                   0.017296
# std                     0.045078                   0.036912
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.001427
# 75%                     0.016461                   0.012987
# max                     1.067669                   0.365385
#
#        coupon_register_per_user_lag14  coupon_daily_per_user_lag14  \
# count                    16752.000000                 16752.000000
# mean                         0.015233                     0.000213
# std                          0.023400                     0.000946
# min                          0.000000                     0.000000
# ...
#
#        trip_cnt_per_user_lag26  nonrepeat_cnt_per_user_lag26  \
# count             14352.000000                  14352.000000
# mean                  0.015044                      0.020410
# std                   0.013803                      0.017785
# min                   0.000000                      0.000000
# 25%                   0.005348                      0.007835
# 50%                   0.011912                      0.016324
# 75%                   0.021798                      0.029333
# max                   0.153846                      0.166667
#
#        match_rate_lag26  coupon_BD_per_user_lag26  coupon_CDP_per_user_lag26  \
# count      14352.000000              14352.000000               14352.000000
# mean           0.700684                  0.206941                   0.382865
# std            0.331687                  0.153430                   0.218554
# min            0.000000                  0.000000                   0.000000
# 25%            0.600000                  0.094340                   0.218880
# 50%            0.800000                  0.179441                   0.341289
# 75%            1.000000                  0.281250                   0.504988
# max            1.000000                  1.156863                   1.303131
#
#        coupon_folk_per_user_lag26  coupon_growth_other_per_user_lag26  \
# count                14352.000000                        14352.000000
# mean                     1.060048                            0.062566
# std                      0.712741                            0.226226
# min                      0.000000                            0.000000
# 25%                      0.921382                            0.000000
# 50%                      0.986236                            0.002608
# 75%                      1.938373                            0.017408
# max                      2.009709                            1.639344
#
#        coupon_MGM_per_user_lag26  coupon_MKT_per_user_lag26  \
# count               14352.000000               14352.000000
# mean                    0.011166                   0.017628
# std                     0.040937                   0.037393
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.002008
# 75%                     0.003296                   0.013283
# max                     1.067669                   0.365385
#
#        coupon_register_per_user_lag26  coupon_daily_per_user_lag26  \
# count                    14352.000000                 14352.000000
# mean                         0.014862                     0.000252
# std                          0.022465                     0.001024
# min                          0.000000                     0.000000
# 25%                          0.000000                     0.000000
# 50%                          0.004329                     0.000000
# 75%                          0.022245                     0.000000
# max                          0.214286                     0.014493
#
#        trip_cnt_per_user_lag27  nonrepeat_cnt_per_user_lag27  \
# count             14136.000000                  14136.000000
# mean                  0.015091                      0.020490
# std                   0.013827                      0.017822
# min                   0.000000                      0.000000
# 25%                   0.005386                      0.007874
# 50%                   0.011976                      0.016393
# 75%                   0.021826                      0.029412
# max                   0.153846                      0.166667
#
#        match_rate_lag27  coupon_BD_per_user_lag27  coupon_CDP_per_user_lag27  \
# count      14136.000000              14136.000000               14136.000000
# mean           0.700686                  0.207486                   0.386097
# std            0.330834                  0.153758                   0.218370
# min            0.000000                  0.000000                   0.000000
# 25%            0.600000                  0.094488                   0.222222
# 50%            0.800000                  0.179856                   0.344444
# 75%            1.000000                  0.282116                   0.508056
# max            1.000000                  1.156863                   1.303131
#
#        coupon_folk_per_user_lag27  coupon_growth_other_per_user_lag27  \
# count                14136.000000                        14136.000000
# mean                     1.056011                            0.063508
# std                      0.712700                            0.227818
# min                      0.000000                            0.000000
# 25%                      0.918919                            0.000000
# 50%                      0.985714                            0.002734
# 75%                      1.936372                            0.017926
# max                      2.009709                            1.639344
#
#        coupon_MGM_per_user_lag27  coupon_MKT_per_user_lag27  \
# count               14136.000000               14136.000000
# mean                    0.010772                   0.017696
# std                     0.040986                   0.037477
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.002069
# 75%                     0.002134                   0.013304
# max                     1.067669                   0.365385
#
#        coupon_register_per_user_lag27  coupon_daily_per_user_lag27  \
# count                    14136.000000                 14136.000000
# mean                         0.014830                     0.000255
# std                          0.022436                     0.001028
# min                          0.000000                     0.000000
# 25%                          0.000000                     0.000000
# 50%                          0.004292                     0.000000
# 75%                          0.022222                     0.000000
# max                          0.214286                     0.014493
#
#        trip_cnt_per_user_lag28  nonrepeat_cnt_per_user_lag28  \
# count             13920.000000                  13920.000000
# mean                  0.015128                      0.020562
# std                   0.013837                      0.017850
# min                   0.000000                      0.000000
# 25%                   0.005414                      0.007937
# 50%                   0.012048                      0.016447
# 75%                   0.021872                      0.029412
# max                   0.153846                      0.166667
#
#        match_rate_lag28  coupon_BD_per_user_lag28  coupon_CDP_per_user_lag28  \
# count      13920.000000              13920.000000               13920.000000
# mean           0.701135                  0.207964                   0.389331
# std            0.329769                  0.154076                   0.218199
# min            0.000000                  0.000000                   0.000000
# 25%            0.600000                  0.094737                   0.224725
# 50%            0.800000                  0.180217                   0.348148
# 75%            1.000000                  0.282459                   0.510085
# max            1.000000                  1.156863                   1.303131
#
#        coupon_folk_per_user_lag28  coupon_growth_other_per_user_lag28  \
# count                13920.000000                        13920.000000
# mean                     1.051707                            0.064479
# std                      0.712541                            0.229444
# min                      0.000000                            0.000000
# 25%                      0.916667                            0.000000
# 50%                      0.985119                            0.002841
# 75%                      1.934190                            0.018156
# max                      2.009709                            1.639344
#
#        coupon_MGM_per_user_lag28  coupon_MKT_per_user_lag28  \
# count               13920.000000               13920.000000
# mean                    0.010938                   0.017764
# std                     0.041281                   0.037560
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.002110
# 75%                     0.002695                   0.013409
# max                     1.067669                   0.365385
#
#        coupon_register_per_user_lag28  coupon_daily_per_user_lag28  \
# count                    13920.000000                 13920.000000
# mean                         0.014777                     0.000258
# std                          0.022376                     0.001033
# min                          0.000000                     0.000000
# 25%                          0.000000                     0.000000
# 50%                          0.004270                     0.000000
# 75%                          0.022210                     0.000000
# max                          0.214286                     0.014493
#
#        trip_cnt_per_user_lag29  nonrepeat_cnt_per_user_lag29  \
# count             13704.000000                  13704.000000
# mean                  0.015095                      0.020498
# std                   0.013819                      0.017799
# min                   0.000000                      0.000000
# 25%                   0.005405                      0.007895
# 50%                   0.011998                      0.016393
# 75%                   0.021798                      0.029412
# max                   0.153846                      0.166667
#
#        match_rate_lag29  coupon_BD_per_user_lag29  coupon_CDP_per_user_lag29  \
# count      13704.000000              13704.000000               13704.000000
# mean           0.701614                  0.207975                   0.392424
# std            0.329603                  0.153753                   0.218201
# min            0.000000                  0.000000                   0.000000
# 25%            0.600000                  0.095105                   0.227273
# 50%            0.800000                  0.179882                   0.350877
# 75%            1.000000                  0.282508                   0.512857
# max            1.000000                  1.156863                   1.303131
#
#        coupon_folk_per_user_lag29  coupon_growth_other_per_user_lag29  \
# count                13704.000000                        13704.000000
# mean                     1.048193                            0.065474
# std                      0.712935                            0.231107
# min                      0.000000                            0.000000
# 25%                      0.916667                            0.000000
# 50%                      0.985222                            0.003027
# 75%                      1.934543                            0.018519
# max                      2.009709                            1.639344
#
#        coupon_MGM_per_user_lag29  coupon_MKT_per_user_lag29  \
# count               13704.000000               13704.000000
# mean                    0.011111                   0.017840
# std                     0.041582                   0.037666
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.002171
# 75%                     0.003060                   0.013440
# max                     1.067669                   0.365385
#
#        coupon_register_per_user_lag29  coupon_daily_per_user_lag29  \
# count                    13704.000000                 13704.000000
# mean                         0.014850                     0.000260
# std                          0.022458                     0.001036
# min                          0.000000                     0.000000
# 25%                          0.000000                     0.000000
# 50%                          0.004302                     0.000000
# 75%                          0.022245                     0.000000
# max                          0.214286                     0.014493
#
#        trip_cnt_per_user_lag30  nonrepeat_cnt_per_user_lag30  \
# count             13488.000000                  13488.000000
# mean                  0.014953                      0.020206
# std                   0.013666                      0.017486
# min                   0.000000                      0.000000
# 25%                   0.005365                      0.007835
# 50%                   0.011900                      0.016131
# 75%                   0.021637                      0.028986
# max                   0.153846                      0.166667
#
#        match_rate_lag30  coupon_BD_per_user_lag30  coupon_CDP_per_user_lag30  \
# count      13488.000000              13488.000000               13488.000000
# mean           0.702919                  0.207875                   0.395460
# std            0.330117                  0.153380                   0.218268
# min            0.000000                  0.000000                   0.000000
# 25%            0.600000                  0.095238                   0.229349
# 50%            0.800000                  0.179825                   0.352941
# 75%            1.000000                  0.282405                   0.516282
# max            1.000000                  1.156863                   1.303131
#
#        coupon_folk_per_user_lag30  coupon_growth_other_per_user_lag30  \
# count                13488.000000                        13488.000000
# mean                     1.044318                            0.066499
# std                      0.713176                            0.232806
# min                      0.000000                            0.000000
# 25%                      0.914956                            0.000000
# 50%                      0.985240                            0.003160
# 75%                      1.933531                            0.018677
# max                      2.009709                            1.639344
#
#        coupon_MGM_per_user_lag30  coupon_MKT_per_user_lag30  \
# count               13488.000000               13488.000000
# mean                    0.011289                   0.017917
# std                     0.041889                   0.037774
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.002253
# 75%                     0.003413                   0.013487
# max                     1.067669                   0.365385
#
#        coupon_register_per_user_lag30  coupon_daily_per_user_lag30  \
# count                    13488.000000                 13488.000000
# mean                         0.014898                     0.000262
# std                          0.022523                     0.001038
# min                          0.000000                     0.000000
# 25%                          0.000000                     0.000000
# 50%                          0.004320                     0.000000
# 75%                          0.022388                     0.000000
# max                          0.214286                     0.014493
#
#             mgm_day
# count  19968.000000
# mean       0.260817
# std        0.439091
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %% [markdown]
# # Face value

# %%
import pandas as pd
import re

IN_PATH  = "../data/daily_trip_with_lag_mgm.csv"
OUT_PATH = "../final_data/data_260129.csv"

df = pd.read_csv(IN_PATH)

def parse_treatment(t):
    if pd.isna(t):
        return 0, 0
    s = str(t).strip()

    # 不發
    if s == "不發":
        return 0, 0

    # 1) 15x2元1張 / 15 x 2 ...
    m = re.search(r"(\d+)\s*[xX]\s*(\d+)", s)
    if m:
        return int(m.group(1)), int(m.group(2))

    # 2) 15元1張 / 15 元 1 張
    m = re.search(r"(\d+)\s*元\s*(\d+)\s*張", s)
    if m:
        return int(m.group(1)), int(m.group(2))

    # 其他格式：先回 NA（你也可改成 0,0）
    return pd.NA, pd.NA

df[["face_value", "face_value_num"]] = df["treatment"].apply(
    lambda x: pd.Series(parse_treatment(x))
)

df["face_value"] = df["face_value"].astype("Int64")
df["face_value_num"] = df["face_value_num"].astype("Int64")

df.to_csv(OUT_PATH, index=False, encoding="utf-8-sig")
print("Saved:", OUT_PATH)
# Out:
# Saved: ../final_data/data_260129.csv

# %% [markdown]
# # split random and control

# %%
import pandas as pd

IN_PATH = "../final_data/data_260129.csv"
OUT_RANDOM  = "../final_data/data_260129_random.csv"
OUT_CONTROL = "../final_data/data_260129_control.csv"

df = pd.read_csv(IN_PATH)

# 以 source 分組（避免有空白）
s = df["source"].astype(str).str.strip()

df_random = df[s.eq("隨機組")].copy()
df_control = df[s.eq("控制組")].copy()

# 如果控制組命名有變體（例如含「控制」兩字），把下面取消註解
# if df_control.empty:
#     df_control = df[s.str.contains("控制", na=False)].copy()

df_random.to_csv(OUT_RANDOM, index=False, encoding="utf-8-sig")
df_control.to_csv(OUT_CONTROL, index=False, encoding="utf-8-sig")

print("rows total  :", len(df))
print("rows random :", len(df_random), "->", OUT_RANDOM)
print("rows control:", len(df_control), "->", OUT_CONTROL)
print("unique source:", sorted(s.dropna().unique()))
# Out:
# rows total  : 19968
# rows random : 16128 -> ../final_data/data_260129_random.csv
# rows control: 3840 -> ../final_data/data_260129_control.csv
# unique source: ['控制組', '隨機組']
