# %%
import pandas as pd

weather = pd.read_csv("../data/weather.csv")

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89540 entries, 0 to 89539
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   cityName        89540 non-null  object
#  1   forecastDate    89540 non-null  object
#  2   temperatureMax  89540 non-null  int64
#  3   temperatureMin  89540 non-null  int64
#  4   narrative       89540 non-null  object
#  5   daypartName     89540 non-null  object
#  6   subNarrative    89540 non-null  object
#  7   precipChance    89540 non-null  int64
#  8   dayOrNight      89540 non-null  object
#  9   publishDate     89540 non-null  object
#  10  create_dt       89540 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 7.5+ MB

# %%
weather.describe()
# Out:
#        temperatureMax  temperatureMin  precipChance
# count    89540.000000    89540.000000  89540.000000
# mean        28.444114       21.944583     33.633616
# std          5.024962        4.855719     25.664377
# min          9.000000        6.000000      0.000000
# 25%         25.000000       18.000000     10.000000
# 50%         30.000000       24.000000     24.000000
# 75%         33.000000       26.000000     58.000000
# max         37.000000       29.000000    100.000000

# %%
pd.set_option("display.max_columns", None)
weather.head()
# Out:
#   cityName forecastDate  temperatureMax  temperatureMin  \
# 0      澎湖縣   2026-01-15              21              20
# 1      澎湖縣   2026-01-15              21              20
# 2      臺東縣   2026-01-15              23              18
# 3      臺東縣   2026-01-15              23              18
# 4      連江縣   2026-01-15              16              14
#
#                        narrative daypartName  \
# 0  午前雲然後午後晴。高溫20到22°C，低溫19到21°C。          今日
# 1  午前雲然後午後晴。高溫20到22°C，低溫19到21°C。          今晚
# 2  午前雲然後午後晴。高溫22到24°C，低溫17到19°C。          今日
# 3  午前雲然後午後晴。高溫22到24°C，低溫17到19°C。          今晚
# 4      大部晴朗。高溫15到17°C，低溫13到15°C。          今晚
#
#                        subNarrative  precipChance dayOrNight publishDate  \
# 0  午前雲然後午後晴。高溫21°C。15到30公里/小時的北北東風。             2          D  2026-01-15
# 1      局部多雲。低溫20°C。25到40公里/小時的北北東風。             4          N  2026-01-15
# 2   午前雲然後午後晴。高溫23°C。10到15公里/小時的東北風。             9          D  2026-01-15
# ...

# %%
earliest = weather.min()
latest   = weather.max()

print("earliest prep_date: \n", earliest)
print("\n latest prep_date: \n", latest)
# Out:
# earliest prep_date:
#  cityName                                           南投縣
# forecastDate                                2025-07-15
# temperatureMax                                       9
# temperatureMin                                       6
# narrative                     午前小雨。高溫12到14°C，低溫9到11°C。
# daypartName                                         今日
# subNarrative      午前小雨。高溫13°C。15到30公里/小時的東北風。降雨機率為80%。
# precipChance                                         0
# dayOrNight                                           D
# publishDate                                 2025-07-15
# create_dt                          2025-07-15 11:52:19
# dtype: object
#
#  latest prep_date:
#  cityName                                          高雄市
# forecastDate                               2026-01-25
# temperatureMax                                     37
# temperatureMin                                     29
# narrative                     雷雨。高溫36到38°C，低溫26到28°C。
# ...
