# %%
import pandas as pd

trip_label = pd.read_csv("../data/trip_label_1.csv")
# Out:
# C:\Users\minhsiang.chang\AppData\Local\Temp\ipykernel_22040\3262525197.py:3: DtypeWarning: Columns (55,58,60,65) have mixed types. Specify dtype option on import or set low_memory=False.
#   trip_label = pd.read_csv("../data/trip_label_1.csv")

# %%
trip_label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2552354 entries, 0 to 2552353
# Data columns (total 66 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   trip_id                    int64
#  1   user_id                    int64
#  2   driver_id                  float64
#  3   week                       object
#  4   trip_date                  object
#  5   trip_time                  object
#  6   weekday                    object
#  7   Hour                       int64
#  8   hour_label                 int64
#  9   order_label                int64
#  10  vehicle_type               object
#  11  sub_vehicle_type           object
#  12  match_vehicle_type         object
#  13  payment_method             object
#  14  coupon_id                  float64
#  15  redeem_value               float64
#  16  net_redeem_value           float64
#  17  reward_points              float64
#  18  promo_title                object
# ...

# %%
trip_label.describe()
# Out:
#             trip_id       user_id     driver_id          Hour    hour_label  \
# count  2.552354e+06  2.552354e+06  2.550034e+06  2.552354e+06  2.552354e+06
# mean   8.187243e+07  2.059067e+06  2.224328e+06  1.327627e+01  2.386530e+00
# std    1.079736e+06  1.426327e+06  1.650261e+06  5.714272e+00  6.528793e-01
# min    7.857651e+07  3.000000e+01  5.100000e+01  0.000000e+00  1.000000e+00
# 25%    8.096574e+07  8.024430e+05  5.992120e+05  9.000000e+00  2.000000e+00
# 50%    8.187258e+07  1.813906e+06  1.979791e+06  1.300000e+01  2.000000e+00
# 75%    8.277592e+07  3.175905e+06  3.862479e+06  1.800000e+01  3.000000e+00
# max    8.383329e+07  5.091162e+06  5.065068e+06  2.300000e+01  3.000000e+00
#
#         order_label     coupon_id  redeem_value  net_redeem_value  \
# count  2.552354e+06  1.288645e+06  1.288645e+06      1.288645e+06
# mean   9.668134e-01  1.516768e+09  2.990230e+01      2.387044e+01
# std    1.791236e-01  2.432772e+07  3.340172e+01      3.175222e+01
# ...

# %%
pd.set_option("display.max_columns", None)
trip_label.head()
# Out:
#     trip_id  user_id  driver_id        week   trip_date            trip_time  \
# 0  83646199   433099     8307.0  2025-10-20  2025-10-26  2025-10-26 11:24:11
# 1  83657857  3032489   361453.0  2025-10-20  2025-10-26  2025-10-26 19:24:52
# 2  83638007  3265377  2004425.0  2025-10-20  2025-10-26  2025-10-26 03:56:23
# 3  83653718  5033731   351996.0  2025-10-20  2025-10-26  2025-10-26 16:55:05
# 4  83663502  2088124  1275850.0  2025-10-20  2025-10-26  2025-10-26 23:34:50
#
#   weekday  Hour  hour_label  order_label vehicle_type sub_vehicle_type  \
# 0     星期日    11           2            1           小黃             一般小黃
# 1     星期日    19           2            1           小黃             一般小黃
# 2     星期日     3           1            1           小黃             一般小黃
# 3     星期日    16           3            1           小黃             一般小黃
# 4     星期日    23           1            1           小黃             一般小黃
#
#   match_vehicle_type payment_method  coupon_id  redeem_value  \
# ...
